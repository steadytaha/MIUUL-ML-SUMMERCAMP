# %% [markdown]
# Görev 1: Seaborn kütüphanesi içerisinden Titanic veri setini tanımlayınız

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Görev 2: Titanic veri setindeki kadın ve erkek yolcuların sayısını bulunuz.

# %%
passengers = df["sex"].value_counts()
print(passengers)
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# Görev 3: Her bir sutuna ait unique değerlerin sayısını bulunuz

# %%
num_uniques = df[[col for col in df.columns]].nunique()
print(num_uniques)
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %% [markdown]
# Görev 4: pclass değişkeninin unique değerlerinin sayısını bulunuz

# %%
pclass = df["pclass"].value_counts()
print(pclass)
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# Görev 5: pclass ve parch değişkenlerinin unique değerlerinin sayısını bulunuz.

# %%
def num_uniques(dataframe, columns):
    for col in columns:
        print(f"--> {dataframe[col].value_counts()} ")

columns = ["pclass", "parch"]
num_uniques(df, columns)
# Out:
# --> pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# --> parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# Görev 6: embarked değişkeninin tipini kontrol ediniz. Tipini category olarak değiştiriniz ve tekrar kontrol ediniz.

# %%
print(df["embarked"].dtype)
# Out:
# object

# %%
df["embarked"] = df["embarked"].astype("category")
print(df["embarked"].dtype)
# Out:
# category

# %% [markdown]
# Görev 7: embarked değeri C olanların tüm bilgelerini gösteriniz

# %%
df[df["embarked"] =="C"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 1          1       1  female  38.0      1      0  71.2833        C   First  \
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 26         0       3    male   NaN      0      0   7.2250        C   Third
# 30         0       1    male  40.0      0      0  27.7208        C   First
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 9   child       False  NaN   Cherbourg   yes  False
# 19  woman       False  NaN   Cherbourg   yes   True
# 26    man        True  NaN   Cherbourg    no   True
# 30    man        True  NaN   Cherbourg    no   True

# %% [markdown]
# Görev 8: embarked değeri S olmayanların tüm bilgelerini gösteriniz.

# %%
df[df["embarked"] != "S"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 1          1       1  female  38.0      1      0  71.2833        C   First  \
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 5     man        True  NaN  Queenstown    no   True
# 9   child       False  NaN   Cherbourg   yes  False
# 16  child       False  NaN  Queenstown    no  False
# 19  woman       False  NaN   Cherbourg   yes   True

# %% [markdown]
# Görev 9: Yaşı 30 dan küçük ve kadın olan yolcuların tüm bilgilerini gösteriniz.

# %%
df[(df["age"] < 30) & (df["sex"] == "female")].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 2          1       3  female  26.0      0      0   7.9250        S   Third  \
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True

# %% [markdown]
# Görev 10: Fare'i 500'den büyük veya yaşı 70 den büyük yolcuların bilgilerini gösteriniz.

# %%
df[(df["fare"] > 500) | (df["age"] > 70)].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class
# 96          0       1    male  71.0      0      0   34.6542        C  First  \
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# 630    man        True    A  Southampton   yes   True

# %% [markdown]
# Görev 11: Her bir değişkendeki boş değerlerin toplamını bulunuz.

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Görev 12: who değişkenini dataframe’den çıkarınız.

# %%
df = df.drop("who", axis=1)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# Görev 13: deck değikenindeki boş değerleri deck değişkenin en çok tekrar eden değeri (mode) ile doldurunuz.

# %%
df = sns.load_dataset('titanic')
print(f" --> {df['deck'].mode()}")
print(f" --> {df['deck'].isnull().sum()}")
# Out:
#  --> 0    C
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']
#  --> 688

# %%
def fill_most(df, col):
    for col in df.columns:
        if df[col].isnull().sum() > 0:
            df[col] = df[col].fillna(df[col].mode()[0])

fill_most(df, "deck")
print(df["deck"].isnull().sum())
# Out:
# 0

# %% [markdown]
# Görev 14: age değikenindeki boş değerleri age değişkenin medyanı ile doldurunuz.

# %%
df = sns.load_dataset('titanic')
print(f"--> Median of 'age'column {df['age'].mean().round(2)}")
print(f"--> Empty values of 'age'column {df['age'].isnull().sum()}")
# Out:
# --> Median of 'age'column 29.7
# --> Empty values of 'age'column 177

# %%
df["age"].fillna(df["age"].mean().round(2), inplace=True)
print(f"--> Empty values of 'age'column after function {df['age'].isnull().sum()}")

df[df["age"] == 29.7].head()
# Out:
# --> Empty values of 'age'column after function 0
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 5          0       3    male  29.7      0      0   8.4583        Q   Third  \
# 17         1       2    male  29.7      0      0  13.0000        S  Second
# 19         1       3  female  29.7      0      0   7.2250        C   Third
# 26         0       3    male  29.7      0      0   7.2250        C   Third
# 28         1       3  female  29.7      0      0   7.8792        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 5     man        True  NaN   Queenstown    no   True
# 17    man        True  NaN  Southampton   yes   True
# 19  woman       False  NaN    Cherbourg   yes   True
# 26    man        True  NaN    Cherbourg    no   True
# 28  woman       False  NaN   Queenstown   yes   True

# %% [markdown]
# Görev 15: survived değişkeninin pclass ve cinsiyet değişkenleri kırılımınında sum, count, mean değerlerini bulunuz.

# %%
df.groupby(["sex", "pclass"]).agg({"survived": ["sum", "count", "mean"],})
# Out:
#               survived
#                    sum count      mean
# sex    pclass
# female 1            91    94  0.968085
#        2            70    76  0.921053
#        3            72   144  0.500000
# male   1            45   122  0.368852
#        2            17   108  0.157407
#        3            47   347  0.135447

# %% [markdown]
# Görev 16: 30 yaşın altında olanlar 1, 30'a eşit ve üstünde olanlara 0 vericek bir fonksiyon yazın. Yazdığınız fonksiyonu kullanarak titanik veri
# setinde age_flag adında bir değişken oluşturunuz oluşturunuz. (apply ve lambda yapılarını kullanınız)

# %%
def age_check(col):
    return col.apply(lambda val: 1 if val < 30 else 0)
     
df["age_flag"] = df.loc[:, df.columns.str.contains("age")].apply(age_check)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_flag
# 0    man        True  NaN  Southampton    no  False         1
# 1  woman       False    C    Cherbourg   yes  False         0
# 2  woman       False  NaN  Southampton   yes   True         1
# 3  woman       False    C  Southampton   yes  False         0
# 4    man        True  NaN  Southampton    no   True         0

# %% [markdown]
# Görev 17: Seaborn kütüphanesi içerisinden Tips veri setini tanımlayınız.

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Görev 18: Time değişkeninin kategorilerine (Dinner, Lunch) göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.

# %%
df.groupby(["time"]).agg({"total_bill": ["min", "max", "mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %% [markdown]
# Görev 19: Günlere ve time göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.

# %%
df.groupby(["day", "time"]).agg({"total_bill": ["min", "max", "mean"]})
# Out:
#             total_bill
#                    min    max       mean
# day  time
# Thur Lunch        7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.780000
# Fri  Lunch        8.58  16.27  12.845714
#      Dinner       5.75  40.17  19.663333
# Sat  Lunch         NaN    NaN        NaN
#      Dinner       3.07  50.81  20.441379
# Sun  Lunch         NaN    NaN        NaN
#      Dinner       7.25  48.17  21.410000

# %% [markdown]
# Görev 20: Lunch zamanına ve kadın müşterilere ait total_bill ve tip değerlerinin day'e göre toplamını, min, max ve ortalamasını bulunuz

# %%
df.loc[(df["sex"] == "Female") & (df["time"] == "Lunch")].agg({"total_bill": ["min", "max", "mean"],
                                                                "tip": ["min", "max", "mean"]})
# Out:
#       total_bill       tip
# min     8.350000  1.250000
# max    43.110000  5.170000
# mean   16.339143  2.582857

# %% [markdown]
# Görev 21: size'i 3'ten küçük, total_bill'i 10'dan büyük olan siparişlerin ortalaması nedir? (loc kullanınız)

# %%
df.loc[(df["size"] < 3) & (df["total_bill"] > 10)].agg({"total_bill": "mean"})
# Out:
# total_bill    17.184965
# dtype: float64

# %% [markdown]
# Görev 22: total_bill_tip_sum adında yeni bir değişken oluşturunuz. Her bir müşterinin ödediği totalbill ve tip in toplamını versin.

# %%
def money(col1, col2):
    return col1 + col2

df["total_bill_tip_sum"] = df.loc[:, ["total_bill", "tip"]].apply(lambda x: money(x["total_bill"], x["tip"]), axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip_sum
# 0       16.99  1.01  Female     No  Sun  Dinner     2               18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3               12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3               24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2               26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4               28.20

# %% [markdown]
# Görev 23: total_bill_tip_sum değişkenine göre büyükten küçüğe sıralayınız ve ilk 30 kişiyi yeni bir dataframe'e atayınız

# %%
import pandas as pd
data = df.nsmallest(30, "total_bill_tip_sum")
data.reset_index().head()
# Out:
#    index  total_bill   tip     sex smoker   day    time  size
# 0     67        3.07  1.00  Female    Yes   Sat  Dinner     1  \
# 1     92        5.75  1.00  Female    Yes   Fri  Dinner     2
# 2    111        7.25  1.00  Female     No   Sat  Dinner     1
# 3    195        7.56  1.44    Male     No  Thur   Lunch     2
# 4    218        7.74  1.44    Male    Yes   Sat  Dinner     2
#
#    total_bill_tip_sum
# 0                4.07
# 1                6.75
# 2                8.25
# 3                9.00
# 4                9.18
